# %% [markdown]
# # S&P 100 Dataset Overview

# %% [markdown]
# ### Authors: </br>
# Ruy Guzmán </br>
# Fernanda de León </br>
# Karla Mondragón

# %% [markdown]
# To download this dataset: https://www.kaggle.com/datasets/alessandrolobello/all-s-and-p100-open-price-stocks-forecast/data?select=sep100.csv

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\karla\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.45.0)
# Requirement already satisfied: pillow>=8 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karla\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\karla\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\karla\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pillow>=8 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karla\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\karla\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\karla\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\karla\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\karla\appdata\roaming\python\python310\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\karla\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install --upgrade nbformat
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbformat in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (2.19.0)
# Requirement already satisfied: jupyter-core in c:\users\karla\appdata\roaming\python\python310\site-packages (from nbformat) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\karla\appdata\roaming\python\python310\site-packages (from nbformat) (5.13.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (4.20.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (0.13.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\karla\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.11.1)
# Requirement already satisfied: pywin32>=300 in c:\users\karla\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat) (306)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\karla\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat) (3.11.0)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\karla\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('sep100.csv')

# %%
df["Date"] = pd.to_datetime(df.Date)
df = df.set_index("Date")
df
# Out:
#                   AAPL         VZ        WBA        WFC         WMT  \
# Date
# 2000-07-13    1.008929  46.315121  30.937500  21.406250   59.125000
# 2000-07-14    1.030134  44.516476  31.250000  21.843750   59.500000
# 2000-07-17    1.041295  44.516476  31.218750  21.687500   60.718750
# 2000-07-18    1.022321  43.898193  31.187500  21.031250   60.062500
# 2000-07-19    0.940848  42.268169  31.312500  21.093750   60.000000
# ...                ...        ...        ...        ...         ...
# 2023-07-07  190.679993  35.900002  29.100000  42.770000  153.490005
# 2023-07-10  188.610001  35.139999  29.790001  42.320000  154.880005
# 2023-07-11  188.080002  34.990002  30.570000  42.740002  154.649994
# 2023-07-12  189.770004  34.860001  30.320000  43.259998  155.039993
# 2023-07-13  190.669998  34.599998  29.735001  43.365002  154.589996
#
#                    XOM         ABT        ADBE          AIG        AMGN  ...  \
# Date                                                                     ...
# 2000-07-13   39.000000   19.583302   34.468750  1603.333374   69.437500  ...
# 2000-07-14   38.781250   19.078287   34.046875  1598.333374   70.750000  ...
# 2000-07-17   39.375000   19.078287   33.765625  1591.666626   72.375000  ...
# 2000-07-18   39.093750   18.825781   32.734375  1589.166626   74.859375  ...
# 2000-07-19   39.343750   18.461048   32.484375  1590.000000   73.437500  ...
# ...                ...         ...         ...          ...         ...  ...
# 2023-07-07  103.160004  106.349998  485.269989    58.200001  218.649994  ...
# 2023-07-10  104.690002  107.019997  496.350006    58.080002  224.729996  ...
# 2023-07-11  105.970001  107.500000  504.739990    58.750000  223.860001  ...
# 2023-07-12  106.489998  106.849998  507.359985    58.650002  225.679993  ...
# 2023-07-13  103.550003  107.065002  516.974976    58.450001  226.880005  ...
#
#                   TMUS        TSLA         TXN         UNH         UNP  \
# Date
# 2000-07-13         NaN         NaN   70.875000   10.718750   10.250000
# 2000-07-14         NaN         NaN   72.500000   10.562500   10.875000
# 2000-07-17         NaN         NaN   73.500000   10.867188   11.015625
# 2000-07-18         NaN         NaN   70.562500   10.406250   10.984375
# 2000-07-19         NaN         NaN   67.250000   10.492188   10.578125
# ...                ...         ...         ...         ...         ...
# 2023-07-07  138.970001  274.429993  173.699997  461.579987  202.820007
# 2023-07-10  138.339996  269.609985  179.440002  463.049988  204.860001
# 2023-07-11  140.020004  269.790009  178.820007  462.890015  206.789993
# 2023-07-12  140.889999  271.989990  182.369995  451.700012  208.919998
# 2023-07-13  140.035004  275.649994  183.654999  449.885010  210.195007
#
#                    UPS        USB           V        ABBV         ACN
# Date
# 2000-07-13   60.312500  21.562500         NaN         NaN         NaN
# 2000-07-14   60.875000  21.937500         NaN         NaN         NaN
# 2000-07-17   60.437500  21.437500         NaN         NaN         NaN
# 2000-07-18   60.750000  20.875000         NaN         NaN         NaN
# 2000-07-19   61.250000  21.062500         NaN         NaN         NaN
# ...                ...        ...         ...         ...         ...
# 2023-07-07  179.759995  33.540001  236.449997  135.500000  305.760010
# 2023-07-10  181.330002  33.740002  238.160004  134.490005  308.450012
# 2023-07-11  185.240005  34.919998  240.550003  135.570007  309.720001
# 2023-07-12  186.490005  35.110001  242.210007  134.979996  313.880005
# 2023-07-13  186.020004  35.465000  243.809998  133.589996  315.445007
#
# [5786 rows x 101 columns]

# %%
columns_list = sorted(df)
with open('column_names', 'w') as fp:
    fp.write("\n".join(str(item) for item in columns_list))

# %% [markdown]
# ### Amazon Stock

# %%
df["AMZN"]
# Out:
# Date
# 2000-07-13      1.750000
# 2000-07-14      2.131250
# 2000-07-17      2.056250
# 2000-07-18      2.087500
# 2000-07-19      2.043750
#                  ...
# 2023-07-07    129.779999
# 2023-07-10    127.129997
# 2023-07-11    128.779999
# 2023-07-12    130.800003
# 2023-07-13    134.418594
# Name: AMZN, Length: 5786, dtype: float64

# %% [markdown]
# ### Finding Co-relation with Amazon (as an example)

# %%
def find_correlated_feature(data_frame, target_feature, threshold=0.9):
    corr_matrix = data_frame.corr()
    highly_correlated_features = corr_matrix[abs(corr_matrix[target_feature]) >= threshold].index.tolist()
    highly_correlated_features.remove(target_feature)
    return highly_correlated_features

amzn_corr = find_correlated_feature(df, "AMZN", threshold = 0.95)

# %%
plt.figure(figsize = (14,8))
sns.heatmap(df[amzn_corr].corr(), annot = True, cmap = "viridis")
plt.show()

# %% [markdown]
# Considering the graph above, we'll select Netflix (NFLX), Google (GOOG), Adobe (ADBE) and Visa (V)

# %%
top_df = df[["AMZN","ADBE","GOOG","NFLX","V"]]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=4, cols=1, shared_xaxes=True, vertical_spacing=0.05)

scatter1 = go.Scatter(x=top_df["ADBE"], y=top_df["AMZN"], mode="markers", name="ADBE vs AMZN")
fig.add_trace(scatter1, row=1, col=1)

scatter2 = go.Scatter(x=top_df["GOOG"], y=top_df["AMZN"], mode="markers", name="GOOG vs AMZN")
fig.add_trace(scatter2, row=2, col=1)

scatter3 = go.Scatter(x=top_df["NFLX"], y=top_df["AMZN"], mode="markers", name="NFLX vs AMZN")
fig.add_trace(scatter3, row=3, col=1)

scatter4 = go.Scatter(x=top_df["V"], y=top_df["AMZN"], mode="markers", name="V vs AMZN")
fig.add_trace(scatter4, row=4, col=1)

fig.update_layout(
    height=800,
    title_text="Correlation between Amazon, Adobe, Google, Netflix & Visa",
)

fig.show()

# %%
top_df.plot(figsize = (15,6),)
plt.title("Trend 2000-2023")
plt.show()

# %% [markdown]
# ### Moving Average for Amazon, Google and Visa

# %%
top_df["AMZN_10"]= top_df["AMZN"].rolling(10).mean()
top_df["AMZN_30"]= top_df["AMZN"].rolling(30).mean()
top_df["AMZN_50"]= top_df["AMZN"].rolling(50).mean()

top_df["GOOG_10"]= top_df["GOOG"].rolling(10).mean()
top_df["GOOG_30"]= top_df["GOOG"].rolling(30).mean()
top_df["GOOG_50"]= top_df["GOOG"].rolling(50).mean()

top_df["V_10"]= top_df["V"].rolling(10).mean()
top_df["V_30"]= top_df["V"].rolling(30).mean()
top_df["V_50"]= top_df["V"].rolling(50).mean()
# Out:
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karla\AppData\Local\Temp\ipykernel_25296\3024525931.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def plot_moviang_avg(df):
    top_df = df.iloc[5200:].copy()
    fig, ax = plt.subplots(2, 2, figsize=(15, 10))
    line_width = 1.5

    ax[0, 0].plot(top_df[["AMZN", "AMZN_10", "AMZN_30", "AMZN_50"]], linewidth=line_width)
    ax[0, 0].set_title("Amazon")
    ax[0, 0].legend(["AMZN", "AMZN_10", "AMZN_30", "AMZN_50"])  
    ax[0, 1].plot(top_df[["V", "V_10", "V_30", "V_50"]], linewidth=line_width)
    ax[0, 1].set_title("Visa")
    ax[0, 1].legend(["V", "V_10", "V_30", "V_50"])  
    ax[1, 0].plot(top_df[["GOOG", "GOOG_10", "GOOG_30", "GOOG_50"]], linewidth=line_width)
    ax[1, 0].set_title("Google")
    ax[1, 0].legend(["GOOG", "GOOG_10", "GOOG_30", "GOOG_50"]) 

    plt.tight_layout()  
    plt.show()

plot_moviang_avg(top_df)

# %%
amazon = top_df[["AMZN", "AMZN_10", "AMZN_30", "AMZN_50"]]
